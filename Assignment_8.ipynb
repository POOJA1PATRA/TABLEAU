# %% [markdown]
# Use the Superstore_USA data and find the customer loyalty on the following
# scenarios
# - How much sales has come from customer from the previous in the current
# year in terms of Sales Value.

# %% [markdown]
# ![salesvalue.png](attachment:salesvalue.png)

# %% [markdown]
# - How much sales has come from customer from the previous in the current
# year in terms of Sales Percentage.

# %% [markdown]
# ![percentage.png](attachment:percentage.png)

# %% [markdown]
# - Find the orders placed by each customers

# %% [markdown]
# ![orders.jpg](attachment:orders.jpg)
