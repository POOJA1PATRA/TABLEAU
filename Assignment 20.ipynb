# %% [markdown]
# Use the Superstore_USA data and do the following
# Create visuals in order to showcase the following visual segments
# - Composition
# - Comapresion
# - Relation
# - Trend
# - Geo Maps

# %% [markdown]
# ![Screenshot%202022-02-07%20at%207.32.06%20PM.png](attachment:Screenshot%202022-02-07%20at%207.32.06%20PM.png)

# %% [markdown]
# ![Screenshot%202022-02-07%20at%207.32.10%20PM.png](attachment:Screenshot%202022-02-07%20at%207.32.10%20PM.png)

# %% [markdown]
# ![Screenshot%202022-02-07%20at%207.32.15%20PM.png](attachment:Screenshot%202022-02-07%20at%207.32.15%20PM.png)

# %% [markdown]
# ![Screenshot%202022-02-07%20at%207.32.28%20PM.png](attachment:Screenshot%202022-02-07%20at%207.32.28%20PM.png)

# %% [markdown]
# ![Screenshot%202022-02-07%20at%207.34.33%20PM.png](attachment:Screenshot%202022-02-07%20at%207.34.33%20PM.png)
