# %% [markdown]
# - Max FDI

# %% [markdown]
# ![MaxFDI.jpg](attachment:MaxFDI.jpg)

# %% [markdown]
# - Min FDI

# %% [markdown]
# ![MinFDI!.png](attachment:MinFDI!.png)

# %% [markdown]
# - FDI Trend

# %% [markdown]
# ![FDI%20Trend.png](attachment:FDI%20Trend.png)

# %% [markdown]
# - Sector Grouping & Comparision

# %% [markdown]
# ![Grouping.png](attachment:Grouping.png)
