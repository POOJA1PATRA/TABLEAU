# %% [markdown]
# Find the inventory by:-
# • Category
# • Sub Category
# • Product
# • Location
# - Create a Dashboard
# - Create a story showing the visuals from Location, Product & Category

# %% [markdown]
# ![Screenshot%202022-02-05%20at%207.00.55%20PM.png](attachment:Screenshot%202022-02-05%20at%207.00.55%20PM.png)
