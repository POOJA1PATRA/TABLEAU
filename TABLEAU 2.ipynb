# %% [markdown]
# Use – Superstore_Canada.xls and format your numbers exactly like shown in screenshot below

# %% [markdown]
# ![Screenshot%202022-02-03%20at%207.25.09%20PM.png](attachment:Screenshot%202022-02-03%20at%207.25.09%20PM.png)

# %% [markdown]
# 2.Use – Superstore_Canada.xls and format your numbers exactly like shown in screenshot below

# %% [markdown]
# ![Screenshot%202022-02-03%20at%207.25.13%20PM.png](attachment:Screenshot%202022-02-03%20at%207.25.13%20PM.png)

# %% [markdown]
# 3.What is the total sales of the store?

# %% [markdown]
# ![Screenshot%202022-02-03%20at%207.25.20%20PM.png](attachment:Screenshot%202022-02-03%20at%207.25.20%20PM.png)

# %% [markdown]
# 4.What is the total sales of product category = “Furniture”?

# %% [markdown]
# ![Screenshot%202022-02-03%20at%207.25.24%20PM.png](attachment:Screenshot%202022-02-03%20at%207.25.24%20PM.png)

# %% [markdown]
# What is the total sales of product category = “Furniture” sold to Customer Segment = “Corporate”?

# %% [markdown]
# ![Screenshot%202022-02-03%20at%207.25.28%20PM.png](attachment:Screenshot%202022-02-03%20at%207.25.28%20PM.png)

# %% [markdown]
# Set the default number format of Discount to percentage with 2 decimal places.

# %% [markdown]
# ![Screenshot%202022-02-03%20at%207.25.31%20PM.png](attachment:Screenshot%202022-02-03%20at%207.25.31%20PM.png)

# %% [markdown]
# Find average discount on each order priority. Which order priority has highest average discount?

# %% [markdown]
# ![Screenshot%202022-02-03%20at%207.25.34%20PM.png](attachment:Screenshot%202022-02-03%20at%207.25.34%20PM.png)
