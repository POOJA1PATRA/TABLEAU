# %% [markdown]
# Use the Store_Data data and do the following
# - Conduct a Market Basket Analysis
# - Perform the required Join Operations to do this.
# - The market basket analysis should be in terms of Product Sub category and
# Order ID

# %% [markdown]
# ![Screenshot%202022-02-09%20at%206.59.13%20PM.png](attachment:Screenshot%202022-02-09%20at%206.59.13%20PM.png)
