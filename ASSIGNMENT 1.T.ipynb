# %% [markdown]
# # SHOW LARGEST SELLING PRODUCTS AND ALSO SHOW WHAT PERCENTAGE OF SALES IS COMING FROM WHICH REGION

# %% [markdown]
# ![ASSIGNMENT%201.A.png](attachment:ASSIGNMENT%201.A.png)

# %% [markdown]
# # CONVERT THE CHART CREATED IN PREVIOUS SLIDE TO 100% STAKED

# %% [markdown]
# ![ASSIGNMEBNT%201.B.png](attachment:ASSIGNMEBNT%201.B.png)

# %% [markdown]
# ### CREATE A SIDE BY SIDE ![ASSIGNMENT%201.png](attachment:ASSIGNMENT%201.png)BAR CHART TO COMPARE ACTUAL VS TARGET SALES OF DIFFERENT PRODUCTS

# %% [markdown]
# CREATE TREE MAP TO SHOW LARGEST SELLING REGIONS

# %% [markdown]
# ![Screenshot%202022-02-01%20at%208.55.13%20PM.png](attachment:Screenshot%202022-02-01%20at%208.55.13%20PM.png)

# %% [markdown]
# ### CREATE PACKED BUBBLE TO SHOW PRODUCT SALES

# %% [markdown]
# ![Screenshot%202022-02-01%20at%208.55.18%20PM.png](attachment:Screenshot%202022-02-01%20at%208.55.18%20PM.png)

# %% [markdown]
# ### SIDE BY SIDE BAR CHART TO COMPASRE ACTUAL VS TARGET SALES OF DIFFERENT PRODUCTS

# %% [markdown]
# ![Screenshot%202022-02-01%20at%208.55.27%20PM.png](attachment:Screenshot%202022-02-01%20at%208.55.27%20PM.png)
