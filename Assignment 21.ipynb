# %% [markdown]
# Use the Demographic_Details and perform the following analysis
# - Find the Death Rate for each State
# - Perform String calculation by creating separat column for the cities without
# the city code
# - Create a Death Rate Category as High, Mid and Low with the help of Logical
# Calculations

# %% [markdown]
# ![Screenshot%202022-02-08%20at%207.36.49%20AM.png](attachment:Screenshot%202022-02-08%20at%207.36.49%20AM.png)

# %% [markdown]
# ![Screenshot%202022-02-08%20at%207.38.07%20AM.png](attachment:Screenshot%202022-02-08%20at%207.38.07%20AM.png)

# %% [markdown]
# ![Screenshot%202022-02-08%20at%207.40.57%20AM.png](attachment:Screenshot%202022-02-08%20at%207.40.57%20AM.png)
