# %% [markdown]
# PROJECT 5:MARKET ANALYSIS:
# get acquainted with self joins (joining the same datasource to itself)
# join the Superstore data to itself based on Order ID and where product sub categories are different
# create the visualisation above matching mine exactly
# create a total sales calculation (sales of both product sub categories when bought together)
# sort the bars by highest total sales first
# create a top n filter to show the top n product sub categories based on total sales

# %% [markdown]
# ![Screenshot%202022-02-14%20at%208.08.40%20PM.png](attachment:Screenshot%202022-02-14%20at%208.08.40%20PM.png)
